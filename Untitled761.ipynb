# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical


# =========================================================
# PATHS
# =========================================================
DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\RJ_Session_247_AU_1955.2.csv"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction"

os.makedirs(OUTPUT_DIR, exist_ok=True)


# =========================================================
# BA FEATURE SELECTION ALGORITHM
# Bat Algorithm
# =========================================================
class BAFeatureSelector:
    def __init__(
        self,
        population_size=20,
        generations=20,
        loudness=0.5,
        pulse_rate=0.5,
        frequency_min=0,
        frequency_max=2
    ):
        self.population_size = population_size
        self.generations = generations
        self.loudness = loudness
        self.pulse_rate = pulse_rate
        self.frequency_min = frequency_min
        self.frequency_max = frequency_max

        self.best_solution = None
        self.best_score = 0
        self.history = []

    def fitness(self, solution, X_train, X_test, y_train, y_test):
        selected_features = np.where(solution == 1)[0]

        if len(selected_features) == 0:
            return 0

        model = RandomForestClassifier(
            n_estimators=100,
            random_state=42
        )

        model.fit(X_train[:, selected_features], y_train)
        predictions = model.predict(X_test[:, selected_features])

        return accuracy_score(y_test, predictions)

    def fit(self, X_train, X_test, y_train, y_test):
        n_features = X_train.shape[1]

        positions = np.random.randint(
            0,
            2,
            size=(self.population_size, n_features)
        )

        velocities = np.zeros((self.population_size, n_features))
        frequencies = np.zeros(self.population_size)

        for i in range(self.population_size):
            if positions[i].sum() == 0:
                positions[i][np.random.randint(0, n_features)] = 1

        fitness_scores = np.zeros(self.population_size)

        for i in range(self.population_size):
            fitness_scores[i] = self.fitness(
                positions[i],
                X_train,
                X_test,
                y_train,
                y_test
            )

        best_index = np.argmax(fitness_scores)
        self.best_solution = positions[best_index].copy()
        self.best_score = fitness_scores[best_index]

        for generation in range(self.generations):

            for i in range(self.population_size):

                frequencies[i] = (
                    self.frequency_min
                    + (self.frequency_max - self.frequency_min)
                    * np.random.rand()
                )

                velocities[i] = (
                    velocities[i]
                    + (positions[i] - self.best_solution)
                    * frequencies[i]
                )

                sigmoid = 1 / (1 + np.exp(-velocities[i]))

                new_solution = np.where(
                    np.random.rand(n_features) < sigmoid,
                    1,
                    0
                )

                if np.random.rand() > self.pulse_rate:
                    random_walk = self.best_solution.copy()
                    mutation_index = np.random.randint(0, n_features)
                    random_walk[mutation_index] = 1 - random_walk[mutation_index]
                    new_solution = random_walk

                if new_solution.sum() == 0:
                    new_solution[np.random.randint(0, n_features)] = 1

                new_score = self.fitness(
                    new_solution,
                    X_train,
                    X_test,
                    y_train,
                    y_test
                )

                if new_score >= fitness_scores[i] and np.random.rand() < self.loudness:
                    positions[i] = new_solution.copy()
                    fitness_scores[i] = new_score

                if new_score > self.best_score:
                    self.best_score = new_score
                    self.best_solution = new_solution.copy()

            self.history.append(self.best_score)

            print(
                f"Generation {generation + 1}/{self.generations} "
                f"| Best BA Accuracy: {self.best_score:.4f}"
            )

        return self.best_solution


# =========================================================
# LOAD DATASET
# =========================================================
df = pd.read_csv(DATASET_PATH)
df.columns = df.columns.str.strip()

print("Dataset Loaded Successfully")
print(df.head())
print(df.columns)


# =========================================================
# CLEAN DATASET
# =========================================================
df = df.dropna()

summary_rows = [
    "Rajasthan",
    "East Rajasthan",
    "West Rajasthan"
]

for row in summary_rows:
    df = df[
        ~df["State/Districts"]
        .astype(str)
        .str.contains(row, case=False, na=False)
    ]


# =========================================================
# TARGET CREATION
# =========================================================
def classify_rainfall(dep):
    if dep <= -20:
        return "Deficient"
    elif dep >= 20:
        return "Excess"
    else:
        return "Normal"


df["Rainfall_Status"] = df["% Dep."].apply(classify_rainfall)

df["Rainfall_Health_Score"] = (
    df["Actual(mm)"] / df["Normal(mm)"]
)


# =========================================================
# LABEL ENCODING
# =========================================================
region_encoder = LabelEncoder()
district_encoder = LabelEncoder()
target_encoder = LabelEncoder()

df["Region_Encoded"] = region_encoder.fit_transform(df["Region"])
df["District_Encoded"] = district_encoder.fit_transform(df["State/Districts"])
df["Target"] = target_encoder.fit_transform(df["Rainfall_Status"])


# =========================================================
# FEATURES
# =========================================================
all_features = [
    "Region_Encoded",
    "District_Encoded",
    "Actual(mm)",
    "Normal(mm)",
    "% Dep.",
    "Rainfall_Health_Score"
]

X = df[all_features]
y = df["Target"]


# =========================================================
# FEATURE SCALING
# =========================================================
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# =========================================================
# TRAIN TEST SPLIT
# =========================================================
stratify_value = y if len(y.unique()) > 1 else None

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42,
    stratify=stratify_value
)


# =========================================================
# BA FEATURE SELECTION
# =========================================================
ba = BAFeatureSelector(
    population_size=20,
    generations=20,
    loudness=0.5,
    pulse_rate=0.5,
    frequency_min=0,
    frequency_max=2
)

best_solution = ba.fit(
    X_train,
    X_test,
    y_train,
    y_test
)

selected_feature_indices = np.where(best_solution == 1)[0]

selected_features = [
    all_features[i]
    for i in selected_feature_indices
]

print("\nBA Selected Features:")
print(selected_features)


# =========================================================
# SELECT BA FEATURES
# =========================================================
X_train_selected = X_train[:, selected_feature_indices]
X_test_selected = X_test[:, selected_feature_indices]
X_scaled_selected = X_scaled[:, selected_feature_indices]


# =========================================================
# FINAL BA RANDOM FOREST MODEL
# =========================================================
ba_model = RandomForestClassifier(
    n_estimators=150,
    random_state=42
)

ba_model.fit(X_train_selected, y_train)

y_pred = ba_model.predict(X_test_selected)

ba_accuracy = accuracy_score(y_test, y_pred)

print("\nFinal BA Accuracy:", ba_accuracy)


# =========================================================
# DEEP LEARNING MODEL
# =========================================================
num_classes = len(np.unique(y))

y_train_cat = to_categorical(y_train, num_classes=num_classes)
y_test_cat = to_categorical(y_test, num_classes=num_classes)

h5_model = Sequential([
    Dense(
        64,
        activation="relu",
        input_shape=(X_train_selected.shape[1],)
    ),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

h5_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = h5_model.fit(
    X_train_selected,
    y_train_cat,
    epochs=50,
    batch_size=4,
    validation_data=(X_test_selected, y_test_cat),
    verbose=1
)


# =========================================================
# SAVE MODELS
# =========================================================
pkl_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_deficiency_model.pkl"
)

h5_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_deficiency_model.h5"
)

joblib.dump(
    {
        "model": ba_model,
        "scaler": scaler,
        "selected_features": selected_features,
        "selected_feature_indices": selected_feature_indices.tolist(),
        "region_encoder": region_encoder,
        "district_encoder": district_encoder,
        "target_encoder": target_encoder,
        "all_features": all_features,
        "algorithm": "Bat Algorithm"
    },
    pkl_path
)

h5_model.save(h5_path)


# =========================================================
# PREDICTIONS
# =========================================================
df["Predicted_Target"] = ba_model.predict(X_scaled_selected)

df["Predicted_Status"] = target_encoder.inverse_transform(
    df["Predicted_Target"]
)

df["Actual_Status"] = df["Rainfall_Status"]


# =========================================================
# SAVE RESULT CSV
# =========================================================
result_csv_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_result.csv"
)

df.to_csv(result_csv_path, index=False)


# =========================================================
# SAVE PREDICTION CSV
# =========================================================
prediction_df = df[
    [
        "Region",
        "State/Districts",
        "Actual(mm)",
        "Normal(mm)",
        "% Dep.",
        "Rainfall_Health_Score",
        "Actual_Status",
        "Predicted_Status"
    ]
]

prediction_csv_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_prediction.csv"
)

prediction_df.to_csv(prediction_csv_path, index=False)


# =========================================================
# SAVE JSON
# =========================================================
json_data = {
    "project_name": "Rainfall Deficiency Prediction using BA",
    "algorithm": "Bat Algorithm",
    "accuracy": float(ba_accuracy),
    "selected_features": selected_features,
    "all_features": all_features,
    "classes": list(target_encoder.classes_),
    "total_records": int(len(df)),
    "files": {
        "pkl": pkl_path,
        "h5": h5_path,
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path
    }
}

json_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_model_results.json"
)

with open(json_path, "w") as f:
    json.dump(json_data, f, indent=4)


# =========================================================
# SAVE YAML
# =========================================================
yaml_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_model_config.yaml"
)

with open(yaml_path, "w") as f:
    yaml.dump(json_data, f, default_flow_style=False)


# =========================================================
# CLASSIFICATION REPORT
# =========================================================
report = classification_report(
    y_test,
    y_pred,
    target_names=target_encoder.classes_,
    zero_division=0
)

report_path = os.path.join(
    OUTPUT_DIR,
    "ba_rainfall_classification_report.txt"
)

with open(report_path, "w") as f:
    f.write(report)


# =========================================================
# BA ACCURACY GRAPH
# =========================================================
plt.figure(figsize=(8, 5))
plt.plot(
    range(1, len(ba.history) + 1),
    ba.history,
    marker="o"
)

plt.title("BA Optimization Accuracy Graph")
plt.xlabel("Generation")
plt.ylabel("Best Accuracy")
plt.grid(True)

accuracy_graph_path = os.path.join(
    OUTPUT_DIR,
    "ba_accuracy_graph.png"
)

plt.savefig(
    accuracy_graph_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# NEURAL NETWORK ACCURACY GRAPH
# =========================================================
plt.figure(figsize=(8, 5))

plt.plot(
    history.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.title("BA Neural Network Accuracy Graph")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

nn_graph_path = os.path.join(
    OUTPUT_DIR,
    "ba_nn_accuracy_graph.png"
)

plt.savefig(
    nn_graph_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# PREDICTION GRAPH
# =========================================================
prediction_counts = prediction_df[
    "Predicted_Status"
].value_counts()

plt.figure(figsize=(8, 5))
prediction_counts.plot(kind="bar")

plt.title("BA Prediction Graph")
plt.xlabel("Predicted Status")
plt.ylabel("District Count")
plt.grid(axis="y")

prediction_graph_path = os.path.join(
    OUTPUT_DIR,
    "ba_prediction_graph.png"
)

plt.savefig(
    prediction_graph_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# RESULT GRAPH
# =========================================================
actual_counts = df[
    "Actual_Status"
].value_counts()

plt.figure(figsize=(8, 5))
actual_counts.plot(kind="bar")

plt.title("BA Result Graph")
plt.xlabel("Actual Status")
plt.ylabel("District Count")
plt.grid(axis="y")

result_graph_path = os.path.join(
    OUTPUT_DIR,
    "ba_result_graph.png"
)

plt.savefig(
    result_graph_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# COMPARISON GRAPH
# =========================================================
comparison_df = pd.DataFrame({
    "Actual": df["Actual_Status"].value_counts(),
    "Predicted": df["Predicted_Status"].value_counts()
}).fillna(0)

comparison_df.plot(
    kind="bar",
    figsize=(9, 6)
)

plt.title("BA Actual vs Predicted Comparison")
plt.xlabel("Rainfall Status")
plt.ylabel("District Count")
plt.grid(axis="y")

comparison_graph_path = os.path.join(
    OUTPUT_DIR,
    "ba_comparison_graph.png"
)

plt.savefig(
    comparison_graph_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# HEATMAP
# =========================================================
plt.figure(figsize=(10, 7))

heatmap_cols = [
    "Actual(mm)",
    "Normal(mm)",
    "% Dep.",
    "Rainfall_Health_Score",
    "Region_Encoded",
    "District_Encoded",
    "Target",
    "Predicted_Target"
]

corr = df[heatmap_cols].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("BA Heatmap")

heatmap_path = os.path.join(
    OUTPUT_DIR,
    "ba_heatmap.png"
)

plt.savefig(
    heatmap_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# CONFUSION MATRIX
# =========================================================
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=target_encoder.classes_,
    yticklabels=target_encoder.classes_
)

plt.title("BA Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

confusion_matrix_path = os.path.join(
    OUTPUT_DIR,
    "ba_confusion_matrix.png"
)

plt.savefig(
    confusion_matrix_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# DISTRICT COMPARISON GRAPH
# =========================================================
plt.figure(figsize=(14, 7))

plt.plot(
    df["State/Districts"],
    df["Actual(mm)"],
    marker="o",
    label="Actual Rainfall"
)

plt.plot(
    df["State/Districts"],
    df["Normal(mm)"],
    marker="x",
    label="Normal Rainfall"
)

plt.title("BA District Rainfall Comparison")
plt.xlabel("District")
plt.ylabel("Rainfall (mm)")
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)

district_graph_path = os.path.join(
    OUTPUT_DIR,
    "ba_district_comparison_graph.png"
)

plt.savefig(
    district_graph_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()


# =========================================================
# FINAL OUTPUT
# =========================================================
print("\nAll BA files saved successfully!")

print("\nSaved Files:")
print("PKL Model:", pkl_path)
print("H5 Model:", h5_path)
print("Result CSV:", result_csv_path)
print("Prediction CSV:", prediction_csv_path)
print("JSON:", json_path)
print("YAML:", yaml_path)
print("Classification Report:", report_path)
print("Accuracy Graph:", accuracy_graph_path)
print("NN Accuracy Graph:", nn_graph_path)
print("Prediction Graph:", prediction_graph_path)
print("Result Graph:", result_graph_path)
print("Comparison Graph:", comparison_graph_path)
print("Heatmap:", heatmap_path)
print("Confusion Matrix:", confusion_matrix_path)
print("District Graph:", district_graph_path)
# Out:
# Dataset Loaded Successfully
#       S. No.          Region State/Districts  Actual(mm)  Normal(mm)  % Dep.
# 0  Rajasthan       Rajasthan       Rajasthan       393.6       419.0      -6
# 1        (i)  East Rajasthan  East Rajasthan       635.3       615.8       3
# 2          1  East Rajasthan           Ajmer       421.0       429.6      -2
# 3          2  East Rajasthan           Alwar       518.1       555.3      -7
# 4          3  East Rajasthan        Banswara       808.3       831.8      -3
# Index(['S. No.', 'Region', 'State/Districts', 'Actual(mm)', 'Normal(mm)',
#        '% Dep.'],
#       dtype='object')
# Generation 1/20 | Best BA Accuracy: 1.0000
# Generation 2/20 | Best BA Accuracy: 1.0000
# Generation 3/20 | Best BA Accuracy: 1.0000
# Generation 4/20 | Best BA Accuracy: 1.0000
# Generation 5/20 | Best BA Accuracy: 1.0000
# Generation 6/20 | Best BA Accuracy: 1.0000
# Generation 7/20 | Best BA Accuracy: 1.0000
# Generation 8/20 | Best BA Accuracy: 1.0000
# Generation 9/20 | Best BA Accuracy: 1.0000
# Generation 10/20 | Best BA Accuracy: 1.0000
# Generation 11/20 | Best BA Accuracy: 1.0000
# Generation 12/20 | Best BA Accuracy: 1.0000
# Generation 13/20 | Best BA Accuracy: 1.0000
# Generation 14/20 | Best BA Accuracy: 1.0000
# Generation 15/20 | Best BA Accuracy: 1.0000
# Generation 16/20 | Best BA Accuracy: 1.0000
# Generation 17/20 | Best BA Accuracy: 1.0000
# Generation 18/20 | Best BA Accuracy: 1.0000
# Generation 19/20 | Best BA Accuracy: 1.0000
# Generation 20/20 | Best BA Accuracy: 1.0000
#
# BA Selected Features:
# ['Region_Encoded', 'Actual(mm)', '% Dep.', 'Rainfall_Health_Score']
#
# Final BA Accuracy: 1.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.4231 - loss: 1.0926 - val_accuracy: 0.7143 - val_loss: 0.9900
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6923 - loss: 0.9431 - val_accuracy: 0.7143 - val_loss: 0.9283
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8077 - loss: 0.8469 - val_accuracy: 0.7143 - val_loss: 0.8724
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7692 - loss: 0.9026 - val_accuracy: 0.8571 - val_loss: 0.8177
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9231 - loss: 0.7611 - val_accuracy: 0.8571 - val_loss: 0.7668
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9615 - loss: 0.6523 - val_accuracy: 0.8571 - val_loss: 0.7208
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8462 - loss: 0.7033 - val_accuracy: 0.7143 - val_loss: 0.6784
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8846 - loss: 0.6011 - val_accuracy: 0.7143 - val_loss: 0.6404
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8846 - loss: 0.5755 - val_accuracy: 0.7143 - val_loss: 0.6028
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9231 - loss: 0.4913 - val_accuracy: 0.8571 - val_loss: 0.5664
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9231 - loss: 0.4618 - val_accuracy: 0.8571 - val_loss: 0.5328
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9615 - loss: 0.4624 - val_accuracy: 0.8571 - val_loss: 0.5029
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8462 - loss: 0.4199 - val_accuracy: 0.8571 - val_loss: 0.4740
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9231 - loss: 0.4616 - val_accuracy: 0.8571 - val_loss: 0.4482
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8462 - loss: 0.4475 - val_accuracy: 0.8571 - val_loss: 0.4270
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8846 - loss: 0.3517 - val_accuracy: 1.0000 - val_loss: 0.4068
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9615 - loss: 0.3287 - val_accuracy: 1.0000 - val_loss: 0.3856
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8846 - loss: 0.3565 - val_accuracy: 1.0000 - val_loss: 0.3640
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9615 - loss: 0.2680 - val_accuracy: 1.0000 - val_loss: 0.3460
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9231 - loss: 0.3223 - val_accuracy: 1.0000 - val_loss: 0.3331
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9231 - loss: 0.2767 - val_accuracy: 1.0000 - val_loss: 0.3204
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.2167 - val_accuracy: 1.0000 - val_loss: 0.3074
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9231 - loss: 0.2268 - val_accuracy: 1.0000 - val_loss: 0.2950
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.2093 - val_accuracy: 1.0000 - val_loss: 0.2840
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.1691 - val_accuracy: 1.0000 - val_loss: 0.2706
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.1789 - val_accuracy: 1.0000 - val_loss: 0.2587
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1791 - val_accuracy: 1.0000 - val_loss: 0.2484
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9615 - loss: 0.1938 - val_accuracy: 1.0000 - val_loss: 0.2403
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1218 - val_accuracy: 1.0000 - val_loss: 0.2367
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9231 - loss: 0.2006 - val_accuracy: 1.0000 - val_loss: 0.2300
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9615 - loss: 0.1734 - val_accuracy: 1.0000 - val_loss: 0.2243
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.1561 - val_accuracy: 1.0000 - val_loss: 0.2195
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9615 - loss: 0.1447 - val_accuracy: 1.0000 - val_loss: 0.2213
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9231 - loss: 0.1729 - val_accuracy: 1.0000 - val_loss: 0.2191
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.1075 - val_accuracy: 1.0000 - val_loss: 0.2127
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.1198 - val_accuracy: 1.0000 - val_loss: 0.2034
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0853 - val_accuracy: 1.0000 - val_loss: 0.1959
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9615 - loss: 0.1311 - val_accuracy: 1.0000 - val_loss: 0.1898
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0907 - val_accuracy: 1.0000 - val_loss: 0.1845
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1098 - val_accuracy: 1.0000 - val_loss: 0.1817
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8846 - loss: 0.1731 - val_accuracy: 1.0000 - val_loss: 0.1787
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9615 - loss: 0.1362 - val_accuracy: 1.0000 - val_loss: 0.1761
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9615 - loss: 0.1097 - val_accuracy: 1.0000 - val_loss: 0.1757
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0762 - val_accuracy: 1.0000 - val_loss: 0.1761
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.1164 - val_accuracy: 1.0000 - val_loss: 0.1708
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0860 - val_accuracy: 1.0000 - val_loss: 0.1671
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9615 - loss: 0.0955 - val_accuracy: 1.0000 - val_loss: 0.1649
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0669 - val_accuracy: 1.0000 - val_loss: 0.1630
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9615 - loss: 0.0733 - val_accuracy: 1.0000 - val_loss: 0.1692
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9615 - loss: 0.0971 - val_accuracy: 1.0000 - val_loss: 0.1651
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# All BA files saved successfully!
#
# Saved Files:
# PKL Model: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_deficiency_model.pkl
# H5 Model: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_deficiency_model.h5
# Result CSV: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_result.csv
# Prediction CSV: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_prediction.csv
# JSON: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_model_results.json
# YAML: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_model_config.yaml
# Classification Report: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_rainfall_classification_report.txt
# Accuracy Graph: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_accuracy_graph.png
# NN Accuracy Graph: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_nn_accuracy_graph.png
# Prediction Graph: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_prediction_graph.png
# Result Graph: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_result_graph.png
# Comparison Graph: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_comparison_graph.png
# Heatmap: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_heatmap.png
# Confusion Matrix: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_confusion_matrix.png
# District Graph: C:\Users\NXTWAVE\Downloads\Rainfall Deficiency Prediction\ba_district_comparison_graph.png
